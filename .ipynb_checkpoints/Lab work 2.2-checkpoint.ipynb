# %% [markdown]
# ___
#
# <a href='https://mainacademy.ua/'> <img src='https://mainacademy.ua/wp-content/uploads/2019/03/logo-main.png' alt = 'Хмм, щось з інтернетом'/></a>
# ___
#
# # Module 2: Basic Python

# %% [markdown]
# ## Lab work 2.2

# %% [markdown]
# #### Мета:
#
# * навчитися працювати із основними інструкціями Python;
# * ознайомитися із базовими алгоритмами;

# %% [markdown]
# ### Завдання 1

# %% [markdown]
# Для трьох введених натуральних чисел (користувач вводить числа через пробіл) знайдіть мінімальне та максимальне

# %%
numbers = input()

l1 = [int(i) for i in numbers.split()]

print(min(l1),max(l1))
# Out:
# 2 7 8
# 2 8

# %% [markdown]
# ### Завдання 2

# %% [markdown]
# Програма приймає на вхід два параметри: стать спортсмена(`sex = (f, m)`) та вік спортсмена(`age = [0,100]`).  Спортсмен-дівчина може брати участь у змаганні, якщо її вік більший 18, спортсмен-хлопець - якщо вік більший 16
#
# Якщо введеніть не коректні дані, виведіть повідомлення про помилку

# %%
sex = input()
age = float(input())

if (sex == 'f' and age >18) | (sex == 'm'and age >16):
    print ('ok')
else:
    print ('not ok')
# Out:
# f
# 2
# not ok

# %% [markdown]
# ### Завдання 3

# %% [markdown]
# Для введеного натурального числа побудуйте драбинку.
#
# Наприклад, якщо N = 5, драбинка буде мати вигляд:
#
# &
#
# &&
#
# &&&
#
# &&&&
#
# &&&&&

# %%
N = int(input())

for i in range(N+1):
    print('&'*i)
# Out:
# 10
#
# &
# &&
# &&&
# &&&&
# &&&&&
# &&&&&&
# &&&&&&&
# &&&&&&&&
# &&&&&&&&&
# &&&&&&&&&&

# %% [markdown]
# ### Завдання 4

# %% [markdown]
# Із заданого речення виведіть кожне слово і його довжину

# %%
sentence = 'My favourite tutor in academy is Ihor'

[print(i) for i in sentence.split()]
print(f'Довжина дорівнює {len([print(i) for i in sentence.split()])}')
# Out:
# My
# favourite
# tutor
# in
# academy
# is
# Ihor
# My
# favourite
# tutor
# in
# academy
# is
# Ihor
# Довжина дорівнює 7

# %% [markdown]
# ### Завдання 5

# %% [markdown]
# Для заданого тексту реалізуйте:
# * Знайдіть кількість слів
# * Знайдіть кількість унікальних слів
# * Своірть словник, де ключе буде слово із тексту, значенням - частота зустрічання в тексті
# * Виведіть топ-3 слів, що найчастіше зустрічаються
#
# Вважаємо, що слово це стрічка з трьох і більше букв, очищена від знаків пунктуації

# %%
text = """До чого ж гарно і весело було в нашому горóді! Ото як вийти з сіней та подивись навколо — геть-чисто все зелене та буйне. А сад було як зацвіте весною! А що робилось на початку літа — огірки цвітуть, гарбузи цвітуть, картопля цвіте. Цвіте малина, смородина, тютюн, квасоля. А соняшника, а маку, буряків, лободи, укропу, моркви! Чого тільки не насадить наша невгамовна мати.

— Нічого в світі так я не люблю, як саджати що-небудь у землю, щоб проізростало. Коли вилізає з землі всяка рослиночка, ото мені радість,— любила проказувати вона.

Город до того переповнявсь рослинами, що десь серед літа вони вже не вміщалися в ньому. Вони лізли одна на одну, переплітались, душились, дерлися на хлів, на стріху, повзли на тин, а гарбузи звисали з тину прямо на вулицю.

А малини — красної, білої! А вишень, а груш солодких, було. як наїсися,— цілий день живіт як бубон.

І росло ще, пригадую, багато тютюну, в якому ми, маленькі, ходили, мов у лісі, в якому пізнали перші мозолі на дитячих руках.

А вздовж тину, за старою повіткою, росли великі кущі смородини, бузини і ще якихось невідомих рослин. Там неслися кури нишком од матері і різне дрібне птаство. Туди ми рідко лазили. Там було темно навіть удень, і ми боялись гадюки. Хто з нас у дитинстві не боявся гадюки, так за все життя й не побачивши її ніде?

Коло хати, що стояла в саду, цвіли квіти, а за хатою, проти сінешніх дверей, коло вишень,— поросла полином стара погребня з одкритою лядою, звідки завжди пахло цвіллю. Там, у льоху, в присмерку плигали жаби. Напевно, там водилися й гадюки.

На погребні любив спати дід.

У нас був дід дуже схожий на бога. Коли я молився богу, я завжди бачив на покуті портрет діда в старих срібнофольгових шатах, а сам дід лежав на печі і тихо кашляв, слухаючи своїх молитов.

У неділю перед богами горіла маленька синенька лампадка, в яку завжди набиралось повно мух. Образ святого Миколая також був схожий на діда, особливо коли дід часом підстригав собі бороду і випивав перед обідом чарку горілки з перцем, і мати не лаялась. Святий Федосій більш скидався на батька. Федосію я не молився, в нього була ще темна борода, а в руці гирлига, одягнена чомусь у білу хустку. А от бог, схожий на діда, той тримав в одній руці круглу сільничку, а трьома пýчками другої неначе збирався взяти зубок часнику
Звали нашого діда, як я вже потім довідавсь, Семеном. Він був високий і худий, і чоло в нього високе, хвилясте довге волосся сиве, а борода біла. І була в нього велика грижа ще з молодих чумацьких літ. Пахнув дід теплою землею і трохи млином. Він був письменний по-церковному і в неділю любив урочисто читати псалтир. Ні дід, ні ми не розуміли прочитаного, і це завжди хвилювало нас, як дивна таємниця, що надавала прочитаному особливого, небуденного смислу.

Мати ненавиділа діда і вважала його за чорнокнижника. Ми не вірили матері і захищали діда од її нападів, бо псалтир всередині був не чорний, а білий, а товста шкіряна палітурка — коричнева, як гречаний мед чи стара халява. Зрештою, мати крадькома таки знищила псалтир. Вона спалила його в печі по одному листочку, боячись палити зразу весь, щоб він часом не вибухнув і не розніс печі.

Любив дід гарну бесіду й добре слово. Часом по дорозі на луг, коли хто питав у нього дорогу на Борзну чи на Батурин, він довго стояв посеред шляху і, махаючи пужалном, гукав услід подорожньому:

— Прямо, та й прямо, та й прямо, та й нікуди ж не звертайте!.. Добра людина поїхала, дай їй бог здоров'я,— зітхав він лагідно, коли подорожній нарешті зникав у кущах.

— А хто вона, діду, людина ота? Звідки вона?

— А бог її знає, хіба я знаю... Ну, чого стоїш як укопаний? — звертався дід до коня, сідаючи на воза.— Но, трогай-бо, ну...

Він був наш добрий дух лугу і риби. Гриби й ягоди збирав він у лісі краще за нас усіх і розмовляв з кіньми, з телятами, з травами, з старою грушею і дубом — з усім живим, що росло і рухалось навколо.
Більш за все на світі любив дід сонце. Він прожив під сонцем коло ста літ, ніколи не ховаючись у холодок. Так під сонцем на погребні, коло яблуні, він і помер, коли прийшов його час.

Дід любив кашляти. Кашляв він часом так довго й гучно, що скільки ми не старалися, ніхто не міг його як слід передражнити. Його кашель чув увесь куток. Старі люди по дідовому кашлю вгадували навіть погоду.
"""

# %%
import string
punct = string.punctuation + '\n'+'—'
punct
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~\n—'

# %%
clean_text = ''.join([t for t in text if t not in punct])
print(f'Кількість слів {len(clean_text.split())}')
print(f'Кількість унікальних слів {len(set(clean_text.split()))}')
# Out:
# Кількість слів 715
# Кількість унікальних слів 465

# %%
d = {}

for word in clean_text.split():
        if word not in d:
            d[word] = 0
        d[word] += 1
d
# Out:
# {'До': 1,
#  'чого': 2,
#  'ж': 2,
#  'гарно': 1,
#  'і': 21,
#  'весело': 1,
#  'було': 4,
#  'в': 16,
#  'нашому': 1,
#  'горóді': 1,
#  'Ото': 1,
#  'як': 10,
#  'вийти': 1,
#  'з': 12,
#  'сіней': 1,
#  'та': 5,
#  'подивись': 1,
#  'навколо': 1,
#  'гетьчисто': 1,
#  'все': 3,
#  'зелене': 1,
#  'буйне': 1,
#  'А': 7,
#  'сад': 1,
#  'зацвіте': 1,
#  'весною': 1,
#  'що': 6,
#  'робилось': 1,
#  'на': 19,
#  'початку': 1,
#  'літа': 2,
#  'огірки': 1,
#  'цвітуть': 2,
#  'гарбузи': 2,
#  'картопля': 1,
#  'цвіте': 1,
#  'Цвіте': 1,
#  'малина': 1,
#  'смородина': 1,
#  'тютюн': 1,
#  'квасоля': 1,
#  'соняшника': 1,
#  'а': 10,
#  'маку': 1,
#  'буряків': 1,
#  'лободи': 1,
#  'укропу': 1,
#  'моркви': 1,
#  'Чого': 1,
#  'тільки': 1,
#  'не': 16,
#  'насадить': 1,
#  'наша': 1,
#  'невгамовна': 1,
#  'мати': 3,
#  'Нічого': 1,
#  'світі': 2,
#  'так': 3,
#  'я': 6,
#  'люблю': 1,
#  'саджати': 1,
#  'щонебудь': 1,
#  'у': 9,
#  'землю': 1,
#  'щоб': 2,
#  'проізростало': 1,
#  'Коли': 2,
#  'вилізає': 1,
#  'землі': 1,
#  'всяка': 1,
#  'рослиночка': 1,
#  'ото': 1,
#  'мені': 1,
#  'радість': 1,
#  'любила': 1,
#  'проказувати': 1,
#  'вонаГород': 1,
#  'до': 2,
#  'того': 1,
#  'переповнявсь': 1,
#  'рослинами': 1,
#  'десь': 1,
#  'серед': 1,
#  'вони': 1,
#  'вже': 2,
#  'вміщалися': 1,
#  'ньому': 1,
#  'Вони': 1,
#  'лізли': 1,
#  'одна': 1,
#  'одну': 1,
#  'переплітались': 1,
#  'душились': 1,
#  'дерлися': 1,
#  'хлів': 1,
#  'стріху': 1,
#  'повзли': 1,
#  'тин': 1,
#  'звисали': 1,
#  'тину': 2,
#  'прямо': 3,
#  'вулицюА': 1,
#  'малини': 1,
#  'красної': 1,
#  'білої': 1,
#  'вишень': 2,
#  'груш': 1,
#  'солодких': 1,
#  'наїсися': 1,
#  'цілий': 1,
#  'день': 1,
#  'живіт': 1,
#  'бубонІ': 1,
#  'росло': 2,
#  'ще': 4,
#  'пригадую': 1,
#  'багато': 1,
#  'тютюну': 1,
#  'якому': 2,
#  'ми': 5,
#  'маленькі': 1,
#  'ходили': 1,
#  'мов': 1,
#  'лісі': 2,
#  'пізнали': 1,
#  'перші': 1,
#  'мозолі': 1,
#  'дитячих': 1,
#  'рукахА': 1,
#  'вздовж': 1,
#  'за': 6,
#  'старою': 2,
#  'повіткою': 1,
#  'росли': 1,
#  'великі': 1,
#  'кущі': 1,
#  'смородини': 1,
#  'бузини': 1,
#  'якихось': 1,
#  'невідомих': 1,
#  'рослин': 1,
#  'Там': 3,
#  'неслися': 1,
#  'кури': 1,
#  'нишком': 1,
#  'од': 2,
#  'матері': 2,
#  'різне': 1,
#  'дрібне': 1,
#  'птаство': 1,
#  'Туди': 1,
#  'рідко': 1,
#  'лазили': 1,
#  'темно': 1,
#  'навіть': 2,
#  'удень': 1,
#  'боялись': 1,
#  'гадюки': 2,
#  'Хто': 1,
#  'нас': 4,
#  'дитинстві': 1,
#  'боявся': 1,
#  'життя': 1,
#  'й': 8,
#  'побачивши': 1,
#  'її': 3,
#  'нідеКоло': 1,
#  'хати': 1,
#  'стояла': 1,
#  'саду': 1,
#  'цвіли': 1,
#  'квіти': 1,
#  'хатою': 1,
#  'проти': 1,
#  'сінешніх': 1,
#  'дверей': 1,
#  'коло': 3,
#  'поросла': 1,
#  'полином': 1,
#  'стара': 2,
#  'погребня': 1,
#  'одкритою': 1,
#  'лядою': 1,
#  'звідки': 1,
#  'завжди': 4,
#  'пахло': 1,
#  'цвіллю': 1,
#  'льоху': 1,
#  'присмерку': 1,
#  'плигали': 1,
#  'жаби': 1,
#  'Напевно': 1,
#  'там': 1,
#  'водилися': 1,
#  'гадюкиНа': 1,
#  'погребні': 2,
#  'любив': 4,
#  'спати': 1,
#  'дідУ': 1,
#  'був': 6,
#  'дід': 8,
#  'дуже': 1,
#  'схожий': 3,
#  'бога': 1,
#  'молився': 2,
#  'богу': 1,
#  'бачив': 1,
#  'покуті': 1,
#  'портрет': 1,
#  'діда': 6,
#  'старих': 1,
#  'срібнофольгових': 1,
#  'шатах': 1,
#  'сам': 1,
#  'лежав': 1,
#  'печі': 2,
#  'тихо': 1,
#  'кашляв': 1,
#  'слухаючи': 1,
#  'своїх': 1,
#  'молитовУ': 1,
#  'неділю': 2,
#  'перед': 2,
#  'богами': 1,
#  'горіла': 1,
#  'маленька': 1,
#  'синенька': 1,
#  'лампадка': 1,
#  'яку': 1,
#  'набиралось': 1,
#  'повно': 1,
#  'мух': 1,
#  'Образ': 1,
#  'святого': 1,
#  'Миколая': 1,
#  'також': 1,
#  'особливо': 1,
#  'коли': 4,
#  'часом': 3,
#  'підстригав': 1,
#  'собі': 1,
#  'бороду': 1,
#  'випивав': 1,
#  'обідом': 1,
#  'чарку': 1,
#  'горілки': 1,
#  'перцем': 1,
#  'лаялась': 1,
#  'Святий': 1,
#  'Федосій': 1,
#  'більш': 1,
#  'скидався': 1,
#  'батька': 1,
#  'Федосію': 1,
#  'нього': 4,
#  'була': 2,
#  'темна': 1,
#  'борода': 2,
#  'руці': 2,
#  'гирлига': 1,
#  'одягнена': 1,
#  'чомусь': 1,
#  'білу': 1,
#  'хустку': 1,
#  'от': 1,
#  'бог': 3,
#  'той': 1,
#  'тримав': 1,
#  'одній': 1,
#  'круглу': 1,
#  'сільничку': 1,
#  'трьома': 1,
#  'пýчками': 1,
#  'другої': 1,
#  'неначе': 1,
#  'збирався': 1,
#  'взяти': 1,
#  'зубок': 1,
#  'часникуЗвали': 1,
#  'нашого': 1,
#  'потім': 1,
#  'довідавсь': 1,
#  'Семеном': 1,
#  'Він': 3,
#  'високий': 1,
#  'худий': 1,
#  'чоло': 1,
#  'високе': 1,
#  'хвилясте': 1,
#  'довге': 1,
#  'волосся': 1,
#  'сиве': 1,
#  'біла': 1,
#  'І': 1,
#  'велика': 1,
#  'грижа': 1,
#  'молодих': 1,
#  'чумацьких': 1,
#  'літ': 2,
#  'Пахнув': 1,
#  'теплою': 1,
#  'землею': 1,
#  'трохи': 1,
#  'млином': 1,
#  'письменний': 1,
#  'поцерковному': 1,
#  'урочисто': 1,
#  'читати': 1,
#  'псалтир': 3,
#  'Ні': 1,
#  'ні': 1,
#  'розуміли': 1,
#  'прочитаного': 1,
#  'це': 1,
#  'хвилювало': 1,
#  'дивна': 1,
#  'таємниця': 1,
#  'надавала': 1,
#  'прочитаному': 1,
#  'особливого': 1,
#  'небуденного': 1,
#  'смислуМати': 1,
#  'ненавиділа': 1,
#  'вважала': 1,
#  'його': 4,
#  'чорнокнижника': 1,
#  'Ми': 1,
#  'вірили': 1,
#  'захищали': 1,
#  'нападів': 1,
#  'бо': 1,
#  'всередині': 1,
#  'чорний': 1,
#  'білий': 1,
#  'товста': 1,
#  'шкіряна': 1,
#  'палітурка': 1,
#  'коричнева': 1,
#  'гречаний': 1,
#  'мед': 1,
#  'чи': 2,
#  'халява': 1,
#  'Зрештою': 1,
#  'крадькома': 1,
#  'таки': 1,
#  'знищила': 1,
#  'Вона': 1,
#  'спалила': 1,
#  'по': 3,
#  'одному': 1,
#  'листочку': 1,
#  'боячись': 1,
#  'палити': 1,
#  'зразу': 1,
#  'весь': 1,
#  'він': 6,
#  'вибухнув': 1,
#  'розніс': 1,
#  'печіЛюбив': 1,
#  'гарну': 1,
#  'бесіду': 1,
#  'добре': 1,
#  'слово': 1,
#  'Часом': 1,
#  'дорозі': 1,
#  'луг': 1,
#  'хто': 2,
#  'питав': 1,
#  'дорогу': 1,
#  'Борзну': 1,
#  'Батурин': 1,
#  'довго': 2,
#  'стояв': 1,
#  'посеред': 1,
#  'шляху': 1,
#  'махаючи': 1,
#  'пужалном': 1,
#  'гукав': 1,
#  'услід': 1,
#  'подорожньому': 1,
#  'Прямо': 1,
#  'нікуди': 1,
#  'звертайте': 1,
#  'Добра': 1,
#  'людина': 2,
#  'поїхала': 1,
#  'дай': 1,
#  'їй': 1,
#  'здоровя': 1,
#  'зітхав': 1,
#  'лагідно': 1,
#  'подорожній': 1,
#  'нарешті': 1,
#  'зникав': 1,
#  'кущах': 1,
#  'вона': 2,
#  'діду': 1,
#  'ота': 1,
#  'Звідки': 1,
#  'знає': 1,
#  'хіба': 1,
#  'знаю': 1,
#  'Ну': 1,
#  'стоїш': 1,
#  'укопаний': 1,
#  'звертався': 1,
#  'коня': 1,
#  'сідаючи': 1,
#  'воза': 1,
#  'Но': 1,
#  'трогайбо': 1,
#  'нуВін': 1,
#  'наш': 1,
#  'добрий': 1,
#  'дух': 1,
#  'лугу': 1,
#  'риби': 1,
#  'Гриби': 1,
#  'ягоди': 1,
#  'збирав': 1,
#  'краще': 1,
#  'усіх': 1,
#  'розмовляв': 1,
#  'кіньми': 1,
#  'телятами': 1,
#  'травами': 1,
#  'грушею': 1,
#  'дубом': 1,
#  'усім': 1,
#  'живим': 1,
#  'рухалось': 1,
#  'навколоБільш': 1,
#  'сонце': 1,
#  'прожив': 1,
#  'під': 2,
#  'сонцем': 2,
#  'ста': 1,
#  'ніколи': 1,
#  'ховаючись': 1,
#  'холодок': 1,
#  'Так': 1,
#  'яблуні': 1,
#  'помер': 1,
#  'прийшов': 1,
#  'часДід': 1,
#  'кашляти': 1,
#  'Кашляв': 1,
#  'гучно': 1,
#  'скільки': 1,
#  'старалися': 1,
#  'ніхто': 1,
#  'міг': 1,
#  'слід': 1,
#  'передражнити': 1,
#  'Його': 1,
#  'кашель': 1,
#  'чув': 1,
#  'увесь': 1,
#  'куток': 1,
#  'Старі': 1,
#  'люди': 1,
#  'дідовому': 1,
#  'кашлю': 1,
#  'вгадували': 1,
#  'погоду': 1}

# %%
print(f'Найчастіше зустрічаються {sorted(d,key=d.get,reverse = True)[:3]}')
# Out:
# Найчастіше зустрічаються ['і', 'на', 'в']

# %% [markdown]
# ### Завдання 6

# %% [markdown]
# Напишіть функції, що:
# * рохраховує мінімальне та максимальне значення
# * середнє значення послідовності
# * медіану послідовності
# * частоту кожної цифри в послідовності
# * середнє квадратичне відхилення
#
# Послідовність чисел ганеруємо рандомно

# %%
import random

#генеруэмо тисячу чисел в діапазоні від 0 до 10
list_with_random_numbers = [random.randint(0,100) for i in range(1000)]

def minimum_maximum(l):
    print(f'мінімальне та максимальне значення {sorted(list_with_random_numbers)[0],sorted(list_with_random_numbers)[-1]}')

# %%
def av(l):
    print(f'середнє значення послідовності {sum(l)/len(l)}')
    print(f'мінімальне та максимальне значення {sorted(list_with_random_numbers)[0],sorted(list_with_random_numbers)[-1]}')
    print(f'медіанa послідовності {sorted(list_with_random_numbers)[500]}')

# %%
av(list_with_random_numbers)
# Out:
# середнє значення послідовності 49.712
# мінімальне та максимальне значення (0, 100)
# медіанa послідовності 48

# %%
def num_freq(l):
    freq = {}

    for i in list_with_random_numbers:
        if i not in freq:
            freq[i] = 0
        freq[i] += 1
    print(f'частотa кожної цифри в послідовності {freq}')

# %%
 num_freq(list_with_random_numbers)
# Out:
# частотa кожної цифри в послідовності {68: 6, 30: 18, 31: 8, 17: 10, 73: 11, 28: 12, 12: 7, 49: 9, 10: 10, 96: 16, 39: 12, 27: 12, 29: 12, 64: 5, 25: 11, 4: 13, 52: 8, 42: 10, 67: 18, 1: 11, 61: 5, 65: 10, 58: 8, 59: 9, 47: 7, 91: 12, 24: 12, 2: 16, 33: 8, 14: 7, 79: 14, 93: 11, 71: 8, 43: 8, 41: 13, 87: 10, 48: 10, 50: 9, 76: 10, 8: 5, 7: 10, 13: 14, 37: 12, 26: 9, 23: 11, 36: 6, 70: 10, 82: 7, 45: 16, 62: 11, 66: 13, 32: 13, 60: 11, 100: 16, 88: 12, 6: 9, 94: 9, 99: 7, 97: 9, 77: 12, 3: 3, 92: 12, 20: 12, 85: 6, 81: 9, 44: 10, 53: 10, 9: 14, 90: 9, 34: 7, 78: 12, 83: 14, 38: 10, 21: 8, 69: 12, 5: 14, 19: 7, 15: 10, 63: 12, 56: 10, 0: 7, 80: 7, 57: 6, 22: 6, 16: 6, 51: 7, 35: 8, 55: 9, 89: 8, 40: 11, 18: 13, 74: 7, 46: 10, 11: 13, 95: 8, 75: 10, 84: 8, 72: 10, 98: 6, 86: 6, 54: 5}

# %%
import math
def stand_dev(l):
    mean_l = sum(l)/len(l)
    res = math.sqrt(sum([(i-mean_l)**2 for i in l])/len(l))
    print(f'середнє квадратичне відхилення {res}')

# %%
stand_dev(list_with_random_numbers)
# Out:
# середнє квадратичне відхилення 29.39219379359088
